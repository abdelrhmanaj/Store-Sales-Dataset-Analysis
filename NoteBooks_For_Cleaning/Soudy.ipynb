# %% [markdown]
# ## CAMPAIGN_TOUCH & CATEGORY & CHANNEL

# %%
import pandas as pd

# Import CAMPAIGN_TOUCH, CATEGORY and CHANNEL files
campaign_touch = pd.read_csv('../DataSet/CAMPAIGN_TOUCH.csv')
category = pd.read_csv('../DataSet/CATEGORY.csv')
channel = pd.read_csv('../DataSet/CHANNEL.csv')

# Display first few rows
print("CAMPAIGN_TOUCH Dataset:")
print(campaign_touch.head())
print("\nCATEGORY Dataset:")
print(category.head())
print("\nCHANNEL Dataset:")
print(channel.head())
# Out:
# CAMPAIGN_TOUCH Dataset:
#       touch_id customer_id  touch_date channel        campaign_name  outcome
# 0  CT000000001  CUST000001  2023-05-08   Email  Health Bundle Offer  Ignored
# 1  CT000000002  CUST000001  2024-01-14     SMS         Weekend Deal  Ignored
# 2  CT000000003  CUST000001  2024-08-22    Push     Subscribe & Save  Ignored
# 3  CT000000004  CUST000001  2023-07-19   Email     Subscribe & Save  Ignored
# 4  CT000000005  CUST000001  2024-01-19    Push     New Launch Promo  Ignored
#
# CATEGORY Dataset:
#   category_id                category_name
# 0      CAT001      Beverages (Coffee/Malt)
# 1      CAT002            Dairy & Nutrition
# 2      CAT003             Infant Nutrition
# 3      CAT004                Confectionery
# 4      CAT005  Culinary (Soups/Seasonings)
#
# CHANNEL Dataset:
#   channel_id   channel_name
# 0      CH001         Online
# 1      CH002     Mobile App
# 2      CH003   Modern Trade
# 3      CH004  General Trade

# %% [markdown]
# # run this after finish all cleaning process

# %%
# Save cleaned datasets
# campaign_touch.to_csv('../Cleaned_DataSet/CAMPAIGN_TOUCH.csv', index=False)
# category.to_csv('../Cleaned_DataSet/CATEGORY.csv', index=False)
# channel.to_csv('../Cleaned_DataSet/CHANNEL.csv', index=False)
# print("Cleaned datasets saved to Cleaned_DataSet folder")

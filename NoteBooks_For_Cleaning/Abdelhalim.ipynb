# %% [markdown]
# ## PROMOTION & STORE & SUPPORT_TICKET

# %%
import pandas as pd

# Import PROMOTION, STORE and SUPPORT_TICKET files
promotion = pd.read_csv('../DataSet/PROMOTION.csv')
store = pd.read_csv('../DataSet/STORE.csv')
support_ticket = pd.read_csv('../DataSet/SUPPORT_TICKET.csv')

# Display first few rows
print("PROMOTION Dataset:")
print(promotion.head())
print("\nSTORE Dataset:")
print(store.head())
print("\nSUPPORT_TICKET Dataset:")
print(support_ticket.head())
# Out:
# PROMOTION Dataset:
#   promo_id promo_type  start_date    end_date  discount_value
# 0  PR00001    PCT_OFF  2025-01-01  2025-01-29            10.0
# 1  PR00002    PCT_OFF  2025-07-11  2025-08-22             5.0
# 2  PR00003       BOGO  2024-11-26  2024-12-24            50.0
# 3  PR00004    PCT_OFF  2025-12-31  2026-01-28            15.0
# 4  PR00005    PCT_OFF  2024-05-30  2024-06-20            10.0
#
# STORE Dataset:
#   store_id store_city    store_state     store_type
# 0   ST0001     Jaipur      Rajasthan  General Trade
# 1   ST0002    Lucknow  Uttar Pradesh    Supermarket
# 2   ST0003     Mysuru      Karnataka    Hypermarket
# 3   ST0004       Gaya          Bihar   Modern Trade
# 4   ST0005   Rourkela         Odisha    Hypermarket
#
# SUPPORT_TICKET Dataset:
#    ticket_id customer_id created_date      issue_type    status  \
# 0  T00000001  CUST001827   2024-07-13  Delivery Delay  Resolved
# 1  T00000002  CUST001394   2025-03-08  Delivery Delay      Open
# 2  T00000003  CUST002568   2026-01-31  Delivery Delay  Resolved
# 3  T00000004  CUST002776   2025-12-24  Delivery Delay  Resolved
# 4  T00000005  CUST006336   2025-12-12    Damaged Item  Resolved
#
#    resolution_time_hr  csat_score
# 0                  23           4
# 1                  18           2
# 2                  66           3
# 3                  20           5
# 4                   7           5

# %% [markdown]
# # run this after finish all cleaning process

# %%
# Save cleaned datasets
# promotion.to_csv('../Cleaned_DataSet/PROMOTION.csv', index=False)
# store.to_csv('../Cleaned_DataSet/STORE.csv', index=False)
# support_ticket.to_csv('../Cleaned_DataSet/SUPPORT_TICKET.csv', index=False)
# print("Cleaned datasets saved to Cleaned_DataSet folder")
